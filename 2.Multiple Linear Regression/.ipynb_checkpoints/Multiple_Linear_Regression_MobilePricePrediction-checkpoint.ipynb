# %%
# Import necessary libraries
# Importing the required libraries for data manipulation, model training, and saving the model.
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pickle

# %%
# Load the dataset
# Loading the dataset from a CSV file.
dataset = pd.read_csv("Diamonds_data.csv")

# %%
# Display the dataset
# Displaying the dataset to ensure it’s loaded correctly.
dataset
# Out:
#        carat        cut color clarity  price     x     y     z
# 0       0.23      Ideal     E     SI2    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
dataset.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'price', 'x', 'y', 'z'], dtype='object')

# %%
dataset=pd.get_dummies(dataset)
dataset
# Out:
#        carat  price     x     y     z  cut_Fair  cut_Good  cut_Ideal  \
# 0       0.23    326  3.95  3.98  2.43     False     False       True
# 1       0.21    326  3.89  3.84  2.31     False     False      False
# 2       0.23    327  4.05  4.07  2.31     False      True      False
# 3       0.29    334  4.20  4.23  2.63     False     False      False
# 4       0.31    335  4.34  4.35  2.75     False      True      False
# ...      ...    ...   ...   ...   ...       ...       ...        ...
# 53935   0.72   2757  5.75  5.76  3.50     False     False       True
# 53936   0.72   2757  5.69  5.75  3.61     False      True      False
# 53937   0.70   2757  5.66  5.68  3.56     False     False      False
# 53938   0.86   2757  6.15  6.12  3.74     False     False      False
# 53939   0.75   2757  5.83  5.87  3.64     False     False       True
#
#        cut_Premium  cut_Very Good  ...  color_I  color_J  clarity_I1  \
# ...

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)
dataset
# Out:
#        carat  price     x     y     z  cut_Fair  cut_Good  cut_Ideal  \
# 0       0.23    326  3.95  3.98  2.43     False     False       True
# 1       0.21    326  3.89  3.84  2.31     False     False      False
# 2       0.23    327  4.05  4.07  2.31     False      True      False
# 3       0.29    334  4.20  4.23  2.63     False     False      False
# 4       0.31    335  4.34  4.35  2.75     False      True      False
# ...      ...    ...   ...   ...   ...       ...       ...        ...
# 53935   0.72   2757  5.75  5.76  3.50     False     False       True
# 53936   0.72   2757  5.69  5.75  3.61     False      True      False
# 53937   0.70   2757  5.66  5.68  3.56     False     False      False
# 53938   0.86   2757  6.15  6.12  3.74     False     False      False
# 53939   0.75   2757  5.83  5.87  3.64     False     False       True
#
#        cut_Premium  cut_Very Good  ...  color_I  color_J  clarity_I1  \
# ...

# %%
dataset.columns
independent = dataset[['carat', 'x', 'y', 'z', 'cut_Fair', 'cut_Good', 'cut_Ideal',
       'cut_Premium', 'cut_Very Good', 'color_D', 'color_E', 'color_F',
       'color_G', 'color_H', 'color_I', 'color_J', 'clarity_I1', 'clarity_IF',
       'clarity_SI1', 'clarity_SI2', 'clarity_VS1', 'clarity_VS2',
       'clarity_VVS1', 'clarity_VVS2']]
dependent = dataset[['price']]

# %%
independent
# Out:
#        carat     x     y     z  cut_Fair  cut_Good  cut_Ideal  cut_Premium  \
# 0       0.23  3.95  3.98  2.43     False     False       True        False
# 1       0.21  3.89  3.84  2.31     False     False      False         True
# 2       0.23  4.05  4.07  2.31     False      True      False        False
# 3       0.29  4.20  4.23  2.63     False     False      False         True
# 4       0.31  4.34  4.35  2.75     False      True      False        False
# ...      ...   ...   ...   ...       ...       ...        ...          ...
# 53935   0.72  5.75  5.76  3.50     False     False       True        False
# 53936   0.72  5.69  5.75  3.61     False      True      False        False
# 53937   0.70  5.66  5.68  3.56     False     False      False        False
# 53938   0.86  6.15  6.12  3.74     False     False      False         True
# 53939   0.75  5.83  5.87  3.64     False     False       True        False
#
# ...

# %%
dependent
# Out:
#        price
# 0        326
# 1        326
# 2        327
# 3        334
# 4        335
# ...      ...
# 53935   2757
# 53936   2757
# 53937   2757
# 53938   2757
# 53939   2757
#
# [53940 rows x 1 columns]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(independent, dependent, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)#y=W*x1+b0 for this equation we got value for b1 and bo
# Out:
# LinearRegression()

# %%
# Viewing the b1 and bo value
weight=regressor.coef_
print("Weight of the model={}".format(weight))
bais=regressor.intercept_
print("Intercept of the model={}".format(bais))
# Out:
# Weight of the model=[[11038.40873374  -833.33771345    14.28542328  -196.78519119
#    -671.69980157   -34.59914654   330.36588487   204.76601629
#     171.16704695   801.08721839   619.70048765   563.31752136
#     342.65336013  -153.67718744  -631.89552278 -1541.18587731
#   -3820.46521427  1531.05914237  -158.67714897 -1126.34990891
#     775.14884155   449.38979327  1211.99928657  1137.89520839]]
# Intercept of the model=[-80.3877895]

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.9202478734535089

# %%
import pickle
filename="final_model_multilinear_diamond_price.sav"
pickle.dump(regressor,open(filename,"wb"))

# %%
model=pickle.load(open(filename,"rb"))

# %% [markdown]
# carat_input = float(input("Enter carat value: "))
# cut_input = int(input("Enter cut_Fair value 0 or 1: "))
# color_input = int(input("Enter color_D value 0 or 1: "))
# clartiy_input = int(input("Enter clarity_I1 value 0 or 1: "))
# x_input = float(input("Enter x value : "))
# y_input = float(input("Enter y value : "))
# z_input = float(input("Enter z value : "))
